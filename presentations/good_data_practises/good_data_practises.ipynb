# %% [raw]
# ---
# title: "Good data practices"
# author: "David Jansen"
# format:
#   revealjs:
#     theme: sky
#     transition: none
# ---

# %% [markdown]
# ```{css}
# .center h2 {
#   text-align: center;
# }
# ```
#
#
# # Content
#
# -   Data
#
# -   Naming
#
# ## Data
#
# -   Keep an as raw as possible version
#
# > -   Consider making your original data file read-only
#
# ::: nonincremental
# > -   keep in a 'save' format
# >     -   Not excel
# >         -   transferring between platforms can cause an issue (e.g. dates)
# :::
#
# > -   Don't make changes to this raw data
#
# > -   create a README
#
# ## Data
#
# > -   Use a scripted program not only for analysis, but also for ***data cleaning*** and ***data wrangling***
#
# ## Data {data-transition="convex"}
#
# -   Try to have content of columns in correct units
#
#     ```
#         | species  | speed    | speed_mph |
#         |----------|----------|-----------|
#         | elephant | 24.9 mph | 24.9      |
#         | mouse    | 8.1 mph  | 8.1       |
#         | cheetah  | 74.6 mph | 74.6      |
#     ```
#
# See Borer *et al* 2009 Some Simple Guidelines for Effective Data Management for details.
#
# ## Naming
#
# > -   descriptive names
#
# > -   Understandable but not to long
#
# > -   But, be aware on naming rules of programs
#
# > -   R names can't start with number and does not like spaces
#
# ::: nonincremental
# > -   styles
# >     -   camelCase
# >     -   snake_case
# >     -   PascalCase
# :::
#
# > -   car_speed_mph versus 'car speed (mph)' versus 'car speed in miles per hour'
#
# > -   avoid special characters (\$, \@, \*)
#
# > -   No spaces !!
#
# > -   case-sensitive (e.g. R) versus case insensitive (SQL)
#
# > -   No spaces !!
#
# ::: callout-tip
# While a computer will ultimately run your code, it'll be read by humans, so write code intended for humans!
# :::
#
# ## Bonus
#
# ### How to deal with R (programming) errors
#
# 1.  don't get frustrated by error messages
#
# 2.  read the error message
#
# 3.  google the error message
#
# 4.  google solutions
#
# 5.  trial and error
#
#     1.  it works --\> go back to your analysis
#
#         ![](good_data_practises_files/images/victory.png)
#
#     2.  error -\> go back to 1.
#
# # No Spaces  :-) {.center}
